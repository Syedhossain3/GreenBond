# %%
# import nltk
# nltk.download('stopwords')

# %%
import pandas as pd
import numpy as np
import os
import string
import glob
import urllib.parse
import nltk
from nltk import word_tokenize
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer

# %%
os.chdir("S:\IFI Applications\Green_Bong_Makerfest\Text_files" )

# %%
data = os.getcwd()
files = os.listdir(data)
stopword_set = nltk.corpus.stopwords.words('english')

# %%
print (os.getcwd())
# Out:
# S:\IFI Applications\Green_Bong_Makerfest\Text_files

# %%
# def clean_column(column_name):
   
#     lemmatizer = nltk.stem.WordNetLemmatizer()    
#     w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
#     stemmer = PorterStemmer()
    
    
#     word_list=[stemmer.stem(lemmatizer.lemmatize(words.lower())) for words in set(w_tokenizer.tokenize(column_name)) 
#                if words.isalpha()
#                if words not in string.punctuation
#                if words.lower() not in stopword_set]
               
    
#     return word_list

# %%
data = []

# try:
for filename in os.listdir("."):
    with open(filename, encoding="utf-8") as f:
        #print("f ", f)
        file =  " ".join(line.strip() for line in f)
        data.append([file, filename])
       
        #print("data and name {}/{}", data)
df = pd.DataFrame(data, columns=['Text', "Name"])
df['Sentence_length'] = df['Text'].apply(lambda x: len(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Text             23 non-null     object
#  1   Name             23 non-null     object
#  2   Sentence_length  23 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 680.0+ bytes

# %%
df['Name']
# Out:
# 0     US_Sustainability Bonds Issuers_fedex_External...
# 1     US_Sustainability Bonds Issuers_Freddie%20Mac%...
# 2     US_Sustainability Bonds Issuers_Goldman-Sachs_...
# 3     US_Sustainability Bonds Issuers_HACC%20Denver_...
# 4     US_Sustainability Bonds Issuers_HP_External%20...
# 5     US_Sustainability Bonds Issuers_JPMC_External%...
# 6     US_Sustainability Bonds Issuers_kellogg_Extern...
# 7     US_Sustainability Bonds Issuers_LIIF_External%...
# 8     US_Sustainability Bonds Issuers_Mastercard_Ext...
# 9     US_Sustainability Bonds Issuers_Metro_External...
# 10    US_Sustainability Bonds Issuers_NRUCFC_Externa...
# 11    US_Sustainability Bonds Issuers_Oncor_External...
# 12    US_Sustainability Bonds Issuers_Pfizer_Externa...
# 13    US_Sustainability Bonds Issuers_salesforce_Ext...
# 14    US_Sustainability Bonds Issuers_Stanford%20Uni...
# 15    US_Sustainability Bonds Issuers_Starbucks_Exte...
# 16    US_Sustainability Bonds Issuers_Sysco_External...
# 17    US_Sustainability Bonds Issuers_Truist-Financi...
# 18    US_Sustainability Bonds Issuers_USAA_External%...
# 19    US_Sustainability Bonds Issuers_whirlpool_Exte...
# 20    US_Sustainability-Linked Bonds Iss_Analog%20De...
# 21    US_Sustainability-Linked Bonds Iss_Newmont_ext...
# 22    Uzbekistan_Sustainability Bonds Issuers_Uzbeki...
# Name: Name, dtype: object

# %%
combined_df = df.copy(deep=True)
combined_basic_df = combined_df.copy(deep=True)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Text             23 non-null     object
#  1   Name             23 non-null     object
#  2   Sentence_length  23 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 680.0+ bytes

# %%
combined_df[['Country', 'BondType','Company','Ext']] = combined_df['Name'].str.split('_', expand=True)
combined_df[['Country']] = combined_df['Country'].str.split('external', expand=True)

# %%
# combined_df = pd.DataFrame(combined_df['Name'].str.split('_',expand=True).rename({0: 'Country', 1: 'BondType', 2:'Company', 3:'Ext'} , axis=1))

# %%
combined_df
# Out:
#                                                  Text  \
# 0   Second-Party Opinion FedEx Corporation Sustain...
# 1   Second-Party Opinion Freddie Mac Multifamily S...
# 2   Second-Party Opinion Goldman Sachs Sustainabil...
# 3   SECOND PARTY OPINION  SUMMARY Kestrel Verifier...
# 4   Second-Party Opinion HP Inc. Sustainable Bond ...
# 5   Second-Party Opinion JPMorgan Chase & Co. Sust...
# 6   Second-Party Opinion Kellogg Sustainability Bo...
# 7   Second-Party Opinion LIIF Sustainability Bond ...
# 8   Second-Party Opinion Mastercard Sustainability...
# 9   SECOND PARTY OPINION – SUSTAINABILITY BONDS  E...
# 10  Second-Party Opinion National Rural Utilities ...
# 11  Second-Party Opinion Oncor Sustainable Bond Fr...
# 12  Second-Party Opinion Pfizer Inc. Sustainabilit...
# 13  Second-Party Opinion Salesforce Sustainable Bo...
# 14  SECOND PARTY OPINION  SUMMARY Kestrel  Verifie...
# 15  STARBUCKS CORPORATION SUSTAINABILITY BOND  FRA...
# 16  Second-Party Opinion Sysco Sustainability Bond...
# 17  Second-Party Opinion Truist Sustainable Financ...
# 18  S ECOND   PARTY  OP INI ON (SP O)  Sustainabil...
# 19  Second-Party Opinion Whirlpool Corporation Sus...
# 20  ANALOG DEVICES SUSTAINABILITY-LINKED FINANCE F...
# 21  S ECOND   PARTY  OP INI ON (SP O)  Sustainabil...
# 22  Second-Party Opinion Republic of Uzbekistan SD...
#
#                                                  Name  Sentence_length  \
# 0   US_Sustainability Bonds Issuers_fedex_External...            52909
# 1   US_Sustainability Bonds Issuers_Freddie%20Mac%...            72608
# 2   US_Sustainability Bonds Issuers_Goldman-Sachs_...            96751
# 3   US_Sustainability Bonds Issuers_HACC%20Denver_...            23611
# 4   US_Sustainability Bonds Issuers_HP_External%20...            85261
# 5   US_Sustainability Bonds Issuers_JPMC_External%...            52945
# 6   US_Sustainability Bonds Issuers_kellogg_Extern...            95184
# 7   US_Sustainability Bonds Issuers_LIIF_External%...            54095
# 8   US_Sustainability Bonds Issuers_Mastercard_Ext...            61273
# 9   US_Sustainability Bonds Issuers_Metro_External...            20903
# 10  US_Sustainability Bonds Issuers_NRUCFC_Externa...            39933
# 11  US_Sustainability Bonds Issuers_Oncor_External...            50401
# 12  US_Sustainability Bonds Issuers_Pfizer_Externa...            54510
# 13  US_Sustainability Bonds Issuers_salesforce_Ext...            71754
# 14  US_Sustainability Bonds Issuers_Stanford%20Uni...            37750
# 15  US_Sustainability Bonds Issuers_Starbucks_Exte...            45656
# 16  US_Sustainability Bonds Issuers_Sysco_External...            55633
# 17  US_Sustainability Bonds Issuers_Truist-Financi...            81661
# 18  US_Sustainability Bonds Issuers_USAA_External%...            47183
# 19  US_Sustainability Bonds Issuers_whirlpool_Exte...            58211
# 20  US_Sustainability-Linked Bonds Iss_Analog%20De...            36567
# 21  US_Sustainability-Linked Bonds Iss_Newmont_ext...           112486
# 22  Uzbekistan_Sustainability Bonds Issuers_Uzbeki...            68530
#
#        Country                         BondType  \
# 0           US     Sustainability Bonds Issuers
# 1           US     Sustainability Bonds Issuers
# 2           US     Sustainability Bonds Issuers
# 3           US     Sustainability Bonds Issuers
# 4           US     Sustainability Bonds Issuers
# 5           US     Sustainability Bonds Issuers
# 6           US     Sustainability Bonds Issuers
# 7           US     Sustainability Bonds Issuers
# 8           US     Sustainability Bonds Issuers
# 9           US     Sustainability Bonds Issuers
# 10          US     Sustainability Bonds Issuers
# 11          US     Sustainability Bonds Issuers
# 12          US     Sustainability Bonds Issuers
# 13          US     Sustainability Bonds Issuers
# 14          US     Sustainability Bonds Issuers
# 15          US     Sustainability Bonds Issuers
# 16          US     Sustainability Bonds Issuers
# 17          US     Sustainability Bonds Issuers
# 18          US     Sustainability Bonds Issuers
# 19          US     Sustainability Bonds Issuers
# 20          US  Sustainability-Linked Bonds Iss
# 21          US  Sustainability-Linked Bonds Iss
# 22  Uzbekistan     Sustainability Bonds Issuers
#
#                                               Company  \
# 0                                               fedex
# 1                      Freddie%20Mac%20Sustainability
# 2                                       Goldman-Sachs
# 3                                       HACC%20Denver
# 4                                                  HP
# 5                                                JPMC
# 6                                             kellogg
# 7                                                LIIF
# 8                                          Mastercard
# 9                                               Metro
# 10                                             NRUCFC
# 11                                              Oncor
# 12                                             Pfizer
# 13                                         salesforce
# 14                              Stanford%20University
# 15                                          Starbucks
# 16                                              Sysco
# 17                                   Truist-Financial
# 18                                               USAA
# 19                                          whirlpool
# 20  Analog%20Devices%20external%20review%20report%...
# 21                                            Newmont
# 22                                         Uzbekistan
#
#                                    Ext
# 0   External%20Review%20Report.pdf.txt
# 1   External%20Review%20Report.pdf.txt
# 2   External%20Review%20Report.pdf.txt
# 3   External%20Review%20Report.pdf.txt
# 4   External%20Review%20Report.pdf.txt
# 5   External%20Review%20Report.pdf.txt
# 6   External%20Review%20Report.pdf.txt
# 7   External%20Review%20Report.pdf.txt
# 8   External%20Review%20Report.pdf.txt
# 9   External%20Review%20Report.pdf.txt
# 10  External%20Review%20Report.pdf.txt
# 11  External%20Review%20Report.pdf.txt
# 12  External%20Review%20Report.pdf.txt
# 13  External%20Review%20Report.pdf.txt
# 14  External%20Review%20Report.pdf.txt
# 15  External%20Review%20Report.pdf.txt
# 16  External%20Review%20Report.pdf.txt
# 17  External%20Review%20Report.pdf.txt
# 18  External%20Review%20Report.pdf.txt
# 19  External%20Review%20Report.pdf.txt
# 20                                None
# 21           external%20review.pdf.txt
# 22  External%20Review%20Report.pdf.txt

# %%
# frame
